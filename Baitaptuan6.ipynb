# %% [markdown]
# <a href="https://colab.research.google.com/github/hnam2007uet/TuDuyTinhToan2026/blob/main/Baitaptuan6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## W6A1
# #### Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữ nguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả. Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
a = list (map (int, input ().split ()))
b = []
for i in a:
  if i not in b:
    b.append (i)
print (b)
# Out:
# 5 5 5 5
# [5]

# %%
a = list (map (int, input ().split ()))
b = set (a)
print (list (b))
# Out:
# 1 2 2 3 3 3 4
# [1, 2, 3, 4]

# %% [markdown]
# ## W6A2
# #### Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị trí i), giữ nguyên thứ tự

# %%
a = list (map (int, input ().split ()))
summ = 0
for i in range (len (a)):
  summ+=a[i]
  a[i] = summ
print (a)
# Out:
# 10 -5 10
# [10, 5, 15]

# %% [markdown]
# ## W6A3
# #### Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp xếp.)

# %%
a = tuple (map (int, input ().split ()))
k = int(input ())
b = a[k:len(a)]
c = a[0:k]
print (b+c)
# Out:
# 5 6
# 2
# (5, 6)

# %%
a = tuple (map (int, input ().split ()))
k = int (input ())
b = []
c= []
if k > len (a):
  print (a)
else:
  for i in range (k, len (a)):
    b.append (a[i])
    for i in range (k):
      c. append (a[i])
    print (tuple (b+c))
# Out:
# 10

# %%
s = input()
k = int(input())

s1 = ""
s2 = ""

i = 0
while i < len(s):
    if i <k:
        s1 = s1 + s[i]
    else:
        s2 = s2 + s[i]
    i += 1

print(s1)
print(s2)
# Out:
# abbbhahuh
# 3
# abb
# bhahuh

# %% [markdown]
# ## W6A4
# #### Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp lại, thêm vào list của key đó

# %%
s = input ().split ()
d = {}
for i in s:
  a, b = i.split (':')
  if a not in d:
    d[a] = []
  d[a].append (b)
print (d)
# Out:
# name:Alice name:Bob age:20
# {'name': ['Alice', 'Bob'], 'age': ['20']}

# %% [markdown]
# ## W6A5
# #### Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros': ...} (đếm số >0, <0, =0)

# %%
a = list(map(int, input().split()))
d = {'positives': 0, 'negatives': 0, 'zeros': 0}
for i in a:
  if i > 0:
    d['positives']+=1
  elif i < 0:
    d['negatives']+=1
  else:
    d['zeros']+=1
print (d)
# Out:
# 1 -1 1 -1
# {'positives': 2, 'negatives': 2, 'zeros': 0}

# %% [markdown]
# ## W6A6
# #### Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số trong list đó.

# %%
a = list (map (int, input().split ()))
summ = 0
for i in a:
  summ+=i
print (summ)
# Out:
# -1 -2 3
# 0

# %% [markdown]
# ## W6A7
# #### Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo ngược

# %%
a = tuple (map (int, input ().split ()))
print (a[0], a[-1], a[::-1])
# Out:
# 5 8 2 7 1 4
# 5 4 (4, 1, 7, 2, 8, 5)

# %% [markdown]
# ## W6A8
# #### Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng chuỗi và lưu vào dictionary.

# %%
a = list (map (str, input ().split ()))
d = {}
for i in a:
  if i in d:
    d[i] += 1
  else:
    d[i] = 1
print (d)
# Out:
# apple banana apple
# {'apple': 2, 'banana': 1}

# %% [markdown]
# ## W6A9
# #### Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành một dictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của key

# %%
d1 = eval(input())
d2 = eval(input())
for i in d2:
  if i in d1:
    d1[i] += d2[i]
  else:
    d1[i] = d2[i]
d1 = dict(sorted(d1.items()))
print(d1)
# Out:
# {'x': 5}
# {}
# {'x': 5}

# %% [markdown]
# ## W6A10
# #### Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple.

# %%
a = list (map (int, input ().split ()))
k = int (input ())
ans = []
for i in range (len (a)):
  b = a[i+1:len(a)]
  if k - a[i] in b and (a[i], k-a[i]) not in ans:
    ans.append ((a[i], k-a[i]))
ans.sort ()
print (ans)
# Out:
# 1 1 2 6 7 2 7 1 7 1
# 8
# [(1, 7), (2, 6), (6, 2), (7, 1)]

# %%
a = list (map (int, input ().split ()))
k =int (input ())
s = set ()
xh = set ()
ans = []
for i in a:
  t = k - i
  if t in s and (t, i) not in xh:
    xh.add ((t, i))
    ans.append ((t,i))
  s.add (i)
ans.sort ()
print (ans)
# Out:
# 1 1 1 1 1
# 2
# [(1, 1)]

# %% [markdown]
# ## W6A11
# #### [Tách số chẵn và lẻ từ tuple]
# #### Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt.

# %%
a = tuple (map (int, input ().split ()))
chan = []
le = []
for i in a:
  if i%2==0:
    chan.append (i)
  else:
    le.append (i)
print (tuple (chan))
print (tuple (le))
# Out:
# 0 -1 -2 -3 -4 5
# (0, -2, -4)
# (-1, -3, 5)

# %% [markdown]
# ## W6A12
# #### [Tìm phần tử xuất hiện nhiều nhất]
# #### Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất trong số đó

# %%
a = list (map (int, input ().split ()))
d= {}
for i in a:
  if i in d:
    d[i] +=1
  else:
    d[i] = 1
maxvl = max (d.values ())
vl = 1e18
for k, v in d.items ():
  if v == maxvl and k < vl:
    vl = k
print (vl)
# Out:
# 1 1 2 2 3 3 3 4 4 4
# 3

# %% [markdown]
# ## W6A13
# #### [Đảo ngược key và value của dictionary]
# #### Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một dictionary mới bằng cách đảo ngược key và value của dictionary ban đầu. In ra dictionary mới.

# %%
s = input().split()
d = {}
for i in range(1,len(s), 2):
    d[s[i]] = s[i-1]
print(d)
# Out:
# code A-1 user B-2 nam C-3
# {'A-1': 'code', 'B-2': 'user', 'C-3': 'nam'}

# %% [markdown]
# ## W6A14
# #### [Giao của hai danh sách]
# #### Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các phần tử chung đó, không trùng lặp

# %%
a = list (map (int, input ().split ()))
b = list (map (int, input ().split ()))
c = []
for i in a:
  if i in b and i not in c:
    c.append (i)
print (c)
# Out:
# 1 2 3 4 5
#
# []

# %% [markdown]
# ## W6A15
# #### [Lọc dictionary theo giá trị]
# #### Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
s = input ().split ()
k = int (input ())
d= {}
for i in range (1, len(s), 2):
  t = int (s[i])
  if t > k:
    d[s[i-1]] = t
print (d)
# Out:
# x -5 y -10 z -2
# -8
# {'x': -5, 'z': -2}

# %%
a = list (map (int, input ().split ()))
maxx = -1e18
for i in a:
  if i>maxx:
    maxx = i
print (maxx)
# Out:
# 5 6 1 8 9 10 5 2
# 10

# %%
a = list (map (int, input ().split ()))
minvl = 1e18
for i in a:
  if i<minvl:
    minvl = i
print (minvl)
# Out:
# 5 6 1 8 9 10 5 2
# 1

# %%
a = list (map (int, input ().split ()))
_sum = 0
for i in a:
  _sum+=i
print (_sum / len(a))
# Out:
# 5 6 1 2 7 7 1 3
# 4.0

# %%
a = list (map (int, input ().split ()))
for i in range (len(a)//2):
  if a[i]!=a[len(a)-1-i]:
    print (False)
    break
else:
  print (True)
# Out:
# 1 2 2 2 1
# True

# %%
a = list (map (int, input ().split ()))
b = []
for i in a:
  if i ==0:
    b. append (i)
    a.remove (i)
print (b+a)
# Out:
# 3 1 4 0 5 0 2
# [0, 0, 3, 1, 4, 5, 2]

# %%
a = list (map (int, input ().split ()))
d = {}
b = []
for i in a:
  if i in d:
    d[i]+=1
  else:
    d[i] = 1
for i in d:
  b.append (i)
print (b)
# Out:
# 2 2 3 3 1 2 4
# [2, 3, 1, 4]

# %%
a = list (map (int, input ().split ()))
checktang = True
checkgiam = True
for i in range (1,len (a)):
  if a[i] < a[i-1]:
    checktang = False
  elif a[i] == a[i-1]:
    checktang = False
    checkgiam = False
  else:
    checkgiam = False
if checktang:
  print ("tang")
elif checkgiam:
  print ("giam")
else:
  print("vodanh")
# Out:
# 1 3 5 6 7 8 9
# tang

# %%
a = list (map (int, input ().split ()))
for i in range (1, len (a)-1):
  if (a[i] > a[i+1] and a[i] > a[i-1]) or (a[i] < a[i+1] and a[i] < a[i-1]):
    continue
  print (False)
  break
else:
  print (True)
# Out:
# 10 2 1 7 2
# False
